# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
print(math.pow(10,3))
print(math.factorial(5))
print(math.sqrt(169))
print(math.ceil(30.9))
print(math.ceil(10.25))
print(math.ceil(10))
print(math.ceil(10.0))
print(math.gcd(2,3,5,7,11))
print(math.lcm(2,4,6,8))
# Out:
# 1000.0
# 120
# 13.0
# 31
# 11
# 10
# 10
# 1
# 24

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
print(random.random()) # this function returns the random float value 0 -1
print(random.randint(1,10))
print(random.randint(1000,9999))
print(random.randint(1,6))
# Out:
# 0.4002838884350368
# 7
# 9391
# 5

# %%
import random
step=0
count=0
while count !=100:
    dice=random.randint(1,6)
    input("to roll a dice, for that click enter button")
    step +=1
    if count + dice <=100:
        count +=dice
        print(f"you are at reach {count} positon in {step} steps")
    else:
        print(f"If you want to reach Top you need {100-count} position")
# Out:
# to roll a dice, for that click enter button
# you are at reach 5 positon in 1 steps
# to roll a dice, for that click enter button
# you are at reach 6 positon in 2 steps
# to roll a dice, for that click enter button
# you are at reach 10 positon in 3 steps
# to roll a dice, for that click enter button
# you are at reach 11 positon in 4 steps
# to roll a dice, for that click enter button
# you are at reach 16 positon in 5 steps
# to roll a dice, for that click enter button
# you are at reach 20 positon in 6 steps
# to roll a dice, for that click enter button
# you are at reach 25 positon in 7 steps
# to roll a dice, for that click enter button
# you are at reach 28 positon in 8 steps
# to roll a dice, for that click enter button
# you are at reach 33 positon in 9 steps
# to roll a dice, for that click enter button
# you are at reach 38 positon in 10 steps
# to roll a dice, for that click enter button
# you are at reach 40 positon in 11 steps
# ...
