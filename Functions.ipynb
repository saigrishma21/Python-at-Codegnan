# %% [markdown]
# #### Functions

# %%
#function defination
def addition(a,b):
    print(a+b)
x=5
y=10
addition(x,y)
# Out:
# 15

# %% [markdown]
# #### With parameters with return

# %%
def addition(a,b):
    c=a+b
    return c
    print("this stmt never execute")
x=5
y=10
addition(x,y)
# Out:
# 15

# %%
def addition(a,b):
    c=a+b
    print("this stmt never execute")
    return c
x=5
y=10
addition(x,y)
# Out:
# this stmt never execute
# 15

# %%
def addition(a,b):
    c=a+b
    return c
x=5
y=10
addition(x,y)
print("this stmt never execute")
# Out:
# this stmt never execute

# %%
def addition(a,b,c):
    d=a+b+c
    return d
x=5
y=10
addition(x,y,8)
print(addition,10,20)
# Out:
# <function addition at 0x00000249C466B740> 10 20

# %% [markdown]
# #### With parameters and without return

# %%
def addition(a,b,c):
    d=a+b+c
x=5
y=10
re=addition(x,y,8)
print(res)
# Out:
# None

# %%
def addition(a,b,c):
    d=a+b+c
    print('this value from funcution defination block:',c)
x=5
y=10
res=addition(x,y,8)
print(res)
# Out:
# this value from funcution defination block: 8
# None

# %% [markdown]
# #### Without parameters without return

# %%
def addition():
    a=5
    b=10
    c=15
    d=a+b+c
    print('this value from funcution defination block:',c)
x=5
y=10
res=addition()
print(res)
# Out:
# this value from funcution defination block: 15
# None

# %% [markdown]
# #### Without parameters with return

# %%
def addition():
    a=5
    b=10
    c=15
    d=a+b+c
    print('this value from funcution defination block:',d)
    return d
x=5
y=10
res=addition()
print(res)
# Out:
# this value from funcution defination block: 30
# 30
