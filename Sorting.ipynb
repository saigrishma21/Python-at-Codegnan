# %% [markdown]
# #### Bubble sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(n-i-1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j+1] = arr[j+1],arr[j]
    return arr
arr = [2,1,7,4]
print(bubble_sort(arr))
# Out:
# [1, 2, 4, 7]

# %% [markdown]
# #### Selection sort

# %%
def selection_sort(arr):
    n=len(arr)
    for i in range(n):
        min_index=i
        for j in range(i+1,n):
            if arr[j]<arr[min_index]:
                min_index=j
        arr[i],arr[min_index]=arr[min_index],arr[i]
    return arr
arr=[2,6,3,1,8]
print(selection_sort(arr))
# Out:
# [1, 2, 3, 6, 8]

# %% [markdown]
# #### Insertion sort

# %%
def insertion_sort(arr):
    n=len(arr)
    for i in range(1,n):
        key=arr[i]
        j=i-1
        while j>=0 and arr[j]>key:
            arr[j+1]=arr[j]
            j -=1
        arr[j+1]=key
    return arr
arr=[5,6,2,3,1]
print(insertion_sort(arr))
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# #### Merge sort

# %%
def merge_sort(arr):
    if len(arr) <=1:
        return arr
    mid=len(arr)//2
    left=merge_sort(arr[:mid])
    right=merge_sort(arr[mid:])
    return merge(left,right)
def merge(left,right):
    result=[]
    i=j=0
    while i<len(left) and j<len(right):
        if left[i]<=right[j]:
            result.append(left[i])
            i +=1
        else:
            result.append(right[j])
            j +=1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
arr=[345,3421,6789,234,1,0,-345,19876]
print(merge_sort(arr))
# Out:
# [-345, 0, 1, 234, 345, 3421, 6789, 19876]

# %% [markdown]
# #### quick sort

# %%
def quick_sort(arr):
    if len(arr) <=1:
        return arr
    pivot =arr[len(arr) //2]
    left=[x for x in arr if x<pivot]
    middle=[x for x in arr if x==pivot]
    right=[x for x in arr if x>pivot]
    return quick_sort(left)+middle+quick_sort(right)
arr=[10,345,132454,1,0,-34]
print(quick_sort(arr))
# Out:
# [-34, 0, 1, 10, 345, 132454]
